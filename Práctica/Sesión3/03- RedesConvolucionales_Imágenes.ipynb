# %% [markdown]
# # Clasificación de imágenes mediante redes neuronales convolucionales (CNN)

# %% [markdown]
# # Importación de librerías

# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from tensorflow.keras.utils import load_img

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
print(os.listdir(r"C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2\inputs"))
# Out:
# C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2
# ['sampleSubmission.csv', 'test1.zip', 'train.zip']

# %% [markdown]
# # Constantes

# %%
FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# # Preparación de los datos de entrenamiento
# Cuidado con la ruta donde tengáis los datos

# %%
filenames = os.listdir(r"C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2\inputs\train\train")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#        filename  category
# 0     cat.0.jpg         0
# 1     cat.1.jpg         0
# 2    cat.10.jpg         0
# 3   cat.100.jpg         0
# 4  cat.1000.jpg         0

# %%
df.tail()
# Out:
#            filename  category
# 24995  dog.9995.jpg         1
# 24996  dog.9996.jpg         1
# 24997  dog.9997.jpg         1
# 24998  dog.9998.jpg         1
# 24999  dog.9999.jpg         1

# %% [markdown]
# ### Vemos la cantidad total de datos que tenemos

# %%
df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Tenemos 12000 gatos y 12000 perros

# %% [markdown]
# # Ejemplo de imagen

# %%
sample = random.choice(filenames)
print (sample)
image = load_img(r"C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2\inputs\train\train\\"+sample)
plt.imshow(image)
# Out:
# dog.12101.jpg

# %% [markdown]
# # Construcción del modelo de red neuronal
#
# <img src="https://i.imgur.com/ebkMGGu.jpg" width="100%"/>

# %% [markdown]
# * **Input Layer**: It represent input image data. It will reshape image into single diminsion array. Example your image is 64x64 = 4096, it will convert to (4096,1) array.
# * **Conv Layer**: This layer will extract features from image.
# * **Pooling Layer**: This layerreduce the spatial volume of input image after convolution.
# * **Fully Connected Layer**: It connect the network from a layer to another layer
# * **Output Layer**: It is the predicted values layer.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

#Capa convolucional 1 con 32 kernels de 3x3, se normalizan los datos, se realiza un pooling de 2x2 donde se simplifica
# la extracción de características y por último, aleatoriamente se desechan el 25% de neuronas
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#Capa convolucional 2 con 64 kernels de 3x3
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

#Capa convolucional 3 con 128 kernels de 3x3
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Añadimos nuestro clasificador
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) # 2 porque sólo clasificamos dos categorías:perros y gatos

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
# ...

# %% [markdown]
# # Callbacks
# Con los callbacks, personalizamos el modelo para ajustar ciertos parámetros

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# **Early Stop**
#
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# **Learning Rate Reduction**
#
# We will reduce the learning rate when then accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# # Prepare data

# %% [markdown]
# Because we will use image genaretor `with class_mode="categorical"`. We need to convert column category into string. Then imagenerator will convert it one-hot encoding which is good for our classification.
#
# So we will convert 1 to dog and 0 to cat

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
validate_df['category'].value_counts().plot.bar()

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %% [markdown]
# # Traning Generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    r"C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2\inputs\train\train\\", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.

# %% [markdown]
# ### Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    r"C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2\inputs\train\train\\", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 5000 validated image filenames belonging to 2 classes.

# %% [markdown]
# # See how our generator work

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    r"C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2\inputs\train\train\\", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# Seem to be nice

# %% [markdown]
# # Fit Model

# %%
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# C:\Users\Francisco\AppData\Local\Temp\ipykernel_33564\612699584.py:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# 1134/1333 [========================>.....] - ETA: 2:02 - loss: 0.7786 - accuracy: 0.6169
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 2
#       1 epochs=3 if FAST_RUN else 50
# ----> 2 history = model.fit_generator(
#       3     train_generator,
#       4     epochs=epochs,
#       5     validation_data=validation_generator,
#       6     validation_steps=total_validate//batch_size,
#       7     steps_per_epoch=total_train//batch_size,
#       8     callbacks=callbacks
#       9 )
#
# ...

# %% [markdown]
# # Save Model

# %%
model.save_weights("model.h5")

# %% [markdown]
# # Virtualize Training

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['acc'], color='b', label="Training accuracy")
ax2.plot(history.history['val_acc'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Prepare Testing Data

# %%
test_filenames = os.listdir(r"C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2\inputs\test1\test1")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %% [markdown]
# # Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    r"C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2\inputs\test1\test1\\", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 12500 validated image filenames.

# %% [markdown]
# # Predict

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %% [markdown]
# For categoral classication the prediction will come with probability of each category. So we will pick the category that have the highest probability with numpy average max

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %% [markdown]
# We will convert the predict category back into our generator classes by using `train_generator.class_indices`. It is the classes that image generator map while converting data into computer vision

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %% [markdown]
# From our prepare data part. We map data with `{1: 'dog', 0: 'cat'}`. Now we will map the result back to dog is 1 and cat is 0

# %%
test_df['category'] = test_df['category'].replace({ 'dog': 1, 'cat': 0 })

# %% [markdown]
# ### Virtaulize Result

# %%
test_df['category'].value_counts().plot.bar()

# %% [markdown]
# ### See predicted result with images

# %%
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img(r"C:\Users\Francisco\Desktop\Jupyter_CursoIA-BD\Sesión 2\inputs\test1\test1\\"+filename, target_size=IMAGE_SIZE)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')' )
plt.tight_layout()
plt.show()
